# %% [raw]
# ---
# title: "Shelby Level"
# about:
#   template: solana
#   image: /logos/headshot_sm.png
#   links:
#    - icon: github
#      text: Github
#      href: https://github.com/shelbylevel
#    - icon: linkedin
#      text: LinkedIn
#      href: https://www.linkedin.com/in/shelby-level-ches-791791232/
#    - icon: envelope
#      text: Email
#      href: mailto:sl165423\\\@ohio.edu
# cv:
#   pdf: "cv.pdf"
# ---

# %% [markdown]
# Hello! I am a graduate student studying Public Administration at Ohio University with an expected graduation of May 2024. I am also a health data analytics and visualization enthusiast looking for an opportunity to continue my learning journey with R.
#
# Check out my CV and example work within the projects and blogs tabs!
#
#
#
# ```{css echo=FALSE}
# .embed-container {
#     position: relative;
#     padding-bottom: 129%;
#     height: 0;
#     overflow: hidden;
#     max-width: 100%;
# }
#
# .embed-container iframe,
# .embed-container object,
# .embed-container embed {
#     position: absolute;
#     top: 0;
#     left: 0;
#     width: 100%;
#     height: 100%;
# }
# ```
#
#
#
#
#
# ## Education
#
# **Ohio University \| Athens, OH** <br> Master of Public Administration \| July 2023 - May 2024
#
# **University of Toledo \| Toledo, OH** <br> B.S in Public Health \| Aug 2020 - May 2023
#
# ## Experience
#
# Ohio University Voinovich School of Leadership and Public Service \| Graduate Assistant \| August 2023 - present
#
# Ohio Alliance for Population Health \| Student Employee \| July 2023 - present
